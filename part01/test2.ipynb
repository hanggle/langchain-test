# %%
import os
import dotenv

dotenv.load_dotenv(override=True)

print(os.getenv("Z_API_KEY"))
# Out:
# 6c14efe058784dad9f6a6c2129a7fc53.hC5hydjGUzYU4HDv

# %%
from langchain_community.chat_models import ChatZhipuAI

chat = ChatZhipuAI(
    model="glm-4.5-flash",
    api_key=os.getenv("Z_API_KEY"),
)


res = chat.invoke("你好， 请介绍下自己")
print(res)
# Out:
# content='你好！我是由智谱AI训练的大语言模型，致力于通过自然语言处理技术为你提供信息和帮助。我可以回答各类问题、提供建议、协助学习创作，也能陪你聊天或探讨感兴趣的话题。我的知识覆盖广泛，会持续学习优化，但也会基于已有信息尽力给出准确、实用的回应。如果你有任何疑问或需求，随时告诉我，我会尽力为你提供支持！' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 303, 'prompt_tokens': 11, 'prompt_tokens_details': {'cached_tokens': 5}, 'total_tokens': 314}, 'model_name': 'glm-4.5-flash', 'finish_reason': 'stop'} id='run-fd96448e-281a-4b10-a2b4-3526da21bc68-0'

# %%
def get_weather(city: str) -> str:
    """Get weather for a given city."""
    return f"It's always sunny in {city}!"

from langchain.agents import  create_agent
agent = create_agent(
    model="glm-4.5-flash",
    tools=[get_weather],
    system_prompt="You are a helpful assistant",
)

agent.invoke(
    {"messages": [{"role": "user", "content": "what is the weather in sf"}]}
)
